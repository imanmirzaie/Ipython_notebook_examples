# %%
import numpy as np
import DataModule as dm

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
d2 = dm.data_2d()
d3 = dm.data_3d()

# %%
d3.load('TwoToneMat_Fig2.dat')

# %%
d3.select()
d3.contourf(colormap=cm.gist_stern)

# %%
d2.x = d3.x ; d2.y = d3.z[0,:]
d2.select()

# %%
d2.plot()

# %%
d2.smooth(2)
d2.plot()

# %%
for i in range(len(d3.y)):
    d3.zsel[i,:] = dm.smooth(d3.x,d3.z[i,:],1)
    
d3.contourf(colormap=cm.gist_stern)
