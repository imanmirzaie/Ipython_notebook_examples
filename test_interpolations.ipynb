# %%
import DataModule as dm
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
d3 = dm.data_3d()

# %%
d3.load('TwoToneMat_Fig2.dat')

# %%
d3.select()
d3.contourf()

# %%
d3.x.shape
# Out:
# (281,)

# %%
d3.y.shape
# Out:
# (412,)

# %%
d3.x.min()
# Out:
# 3880000000.0

# %%
xnew = linspace(d3.x.min(),d3.x.max(),100)
ynew = linspace(d3.y.min(),d3.y.max(),100)

# %%
d3.interp(xnew,ynew)
d3.contourf()

# %% [markdown]
# Testing for 2D data

# %%
d2 = dm.data_2d()

# %%
d2.x = d3.x
d2.y = d3.z[0,:]
d2.select()
d2.plot()

# %%
d2.x.shape
# Out:
# (281,)

# %%
xnew1 = linspace(d2.x.min(),d2.x.max(),1000)
d2.select()
d2.interp(xnew1)
d2.plot()

# %%
d2.select()
d2.smooth(5)
d2.plot()
