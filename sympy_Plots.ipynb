# %%
import sympy as sp
# %pylab inline

sp.init_printing()
plt.rc('figure', figsize=(12, 9))
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = sp.symbols('x')
sp.plot(sp.sin(x),(x,-10,10))

# %%
sp.plot(sp.atan(x),(x,-20,20))
