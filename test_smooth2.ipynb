# %%
import numpy as np
import DataModule as dm

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
d3 = dm.data_3d()

# %%
d3.load('TwoToneMat_Fig2.dat')

# %%
d3.select()
d3.contourf(colormap=cm.gist_stern)

# %%
d3.select()
d3.smoothx(3)
d3.contourf(colormap=cm.gist_stern)

# %%
d3.select()
d3.smoothy(3)
d3.contourf(colormap=cm.gist_stern)
